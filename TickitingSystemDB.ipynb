-- %% [markdown]
-- # [POS]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [POS]    Script Date: 8/21/2022 9:40:02 AM ******/
CREATE DATABASE [POS]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'POS', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\POS.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'POS_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\POS_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [POS] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [POS].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [POS] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [POS] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [POS] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [POS] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [POS] SET ARITHABORT OFF 
GO
ALTER DATABASE [POS] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [POS] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [POS] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [POS] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [POS] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [POS] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [POS] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [POS] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [POS] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [POS] SET  DISABLE_BROKER 
GO
ALTER DATABASE [POS] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [POS] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [POS] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [POS] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [POS] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [POS] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [POS] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [POS] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [POS] SET  MULTI_USER 
GO
ALTER DATABASE [POS] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [POS] SET DB_CHAINING OFF 
GO
ALTER DATABASE [POS] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [POS] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [POS] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [POS] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [POS] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[Block]

-- %%
USE [POS]
GO

-- %%
/****** Object:  Table [dbo].[Block]    Script Date: 8/21/2022 9:40:02 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Block](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[HallId] [int] NOT NULL,
	[Width] [int] NOT NULL,
	[Height] [int] NOT NULL,
	[Capacity]  AS ([Width]*[Height]),
	[Angle] [int] NOT NULL,
	[Left] [int] NOT NULL,
	[Top] [int] NOT NULL,
	[Right] [int] NOT NULL,
	[Bottom] [int] NOT NULL,
 CONSTRAINT [PK_Block] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Event]

-- %%
/****** Object:  Table [dbo].[Event]    Script Date: 8/21/2022 9:40:02 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Event](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Name] [nvarchar](50) NOT NULL,
	[Date] [date] NOT NULL,
	[Time] [time](7) NOT NULL,
	[Duration] [int] NOT NULL,
	[HallID] [int] NOT NULL,
	[End]  AS (dateadd(hour,[Duration],[Time])),
 CONSTRAINT [PK_Event] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [IX_Event] UNIQUE NONCLUSTERED 
(
	[HallID] ASC,
	[Date] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Hall]

-- %%
/****** Object:  Table [dbo].[Hall]    Script Date: 8/21/2022 9:40:02 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Hall](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Name] [nvarchar](50) NOT NULL,
 CONSTRAINT [PK_Hall] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [UN_Table_1] UNIQUE NONCLUSTERED 
(
	[Name] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Price]

-- %%
/****** Object:  Table [dbo].[Price]    Script Date: 8/21/2022 9:40:02 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Price](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[EventId] [int] NOT NULL,
	[BlockId] [int] NOT NULL,
	[Price] [int] NOT NULL,
	[Idx] [int] NOT NULL,
 CONSTRAINT [PK_Price] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [IX_Price] UNIQUE NONCLUSTERED 
(
	[BlockId] ASC,
	[EventId] ASC,
	[Idx] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Reservation]

-- %%
/****** Object:  Table [dbo].[Reservation]    Script Date: 8/21/2022 9:40:02 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Reservation](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[Name] [nvarchar](50) NOT NULL,
	[Mail] [nvarchar](50) NOT NULL,
	[Cost] [int] NOT NULL,
	[EventId] [int] NOT NULL,
 CONSTRAINT [PK_Reservation] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
 CONSTRAINT [IX_Reservation_1] UNIQUE NONCLUSTERED 
(
	[Mail] ASC,
	[EventId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Ticket]

-- %%
/****** Object:  Table [dbo].[Ticket]    Script Date: 8/21/2022 9:40:02 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Ticket](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[ReservationId] [int] NOT NULL,
	[BlockId] [int] NOT NULL,
	[SeatX] [int] NOT NULL,
	[SeatY] [int] NOT NULL,
 CONSTRAINT [PK_Ticket] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_Block_Hall]

-- %%
ALTER TABLE [dbo].[Block]  WITH CHECK ADD  CONSTRAINT [FK_Block_Hall] FOREIGN KEY([HallId])
REFERENCES [dbo].[Hall] ([ID])
GO
ALTER TABLE [dbo].[Block] CHECK CONSTRAINT [FK_Block_Hall]
GO

-- %% [markdown]
-- # [FK_Event_Hall]

-- %%
ALTER TABLE [dbo].[Event]  WITH CHECK ADD  CONSTRAINT [FK_Event_Hall] FOREIGN KEY([HallID])
REFERENCES [dbo].[Hall] ([ID])
GO
ALTER TABLE [dbo].[Event] CHECK CONSTRAINT [FK_Event_Hall]
GO

-- %% [markdown]
-- # [FK_Price_Block]

-- %%
ALTER TABLE [dbo].[Price]  WITH CHECK ADD  CONSTRAINT [FK_Price_Block] FOREIGN KEY([BlockId])
REFERENCES [dbo].[Block] ([ID])
GO
ALTER TABLE [dbo].[Price] CHECK CONSTRAINT [FK_Price_Block]
GO

-- %% [markdown]
-- # [FK_Price_Event]

-- %%
ALTER TABLE [dbo].[Price]  WITH CHECK ADD  CONSTRAINT [FK_Price_Event] FOREIGN KEY([EventId])
REFERENCES [dbo].[Event] ([ID])
GO
ALTER TABLE [dbo].[Price] CHECK CONSTRAINT [FK_Price_Event]
GO

-- %% [markdown]
-- # [FK_Reservation_Event]

-- %%
ALTER TABLE [dbo].[Reservation]  WITH CHECK ADD  CONSTRAINT [FK_Reservation_Event] FOREIGN KEY([EventId])
REFERENCES [dbo].[Event] ([ID])
GO
ALTER TABLE [dbo].[Reservation] CHECK CONSTRAINT [FK_Reservation_Event]
GO

-- %% [markdown]
-- # [FK_Ticket_Block]

-- %%
ALTER TABLE [dbo].[Ticket]  WITH CHECK ADD  CONSTRAINT [FK_Ticket_Block] FOREIGN KEY([BlockId])
REFERENCES [dbo].[Block] ([ID])
GO
ALTER TABLE [dbo].[Ticket] CHECK CONSTRAINT [FK_Ticket_Block]
GO

-- %% [markdown]
-- # [FK_Ticket_Reservation]

-- %%
ALTER TABLE [dbo].[Ticket]  WITH CHECK ADD  CONSTRAINT [FK_Ticket_Reservation] FOREIGN KEY([ReservationId])
REFERENCES [dbo].[Reservation] ([ID])
GO
ALTER TABLE [dbo].[Ticket] CHECK CONSTRAINT [FK_Ticket_Reservation]
GO

-- %% [markdown]
-- # [dbo].[addBlock]

-- %%
/****** Object:  StoredProcedure [dbo].[addBlock]    Script Date: 8/21/2022 9:40:02 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[addBlock]
(@hall int,
@w int,
@h int,
@a int,
@l int,@t int,@r int,@b int)
as

begin

	Insert into Block 
	(HallId, Width, Height, Angle, [Left], [Top], [Right] , Bottom)
	Values
	(@hall, @w, @h, @a, @l,@t, @r,@b)
	
end
GO

-- %% [markdown]
-- # [dbo].[addEvent]

-- %%
/****** Object:  StoredProcedure [dbo].[addEvent]    Script Date: 8/21/2022 9:40:02 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[addEvent]
(@hall int,
@name nvarchar(50),
@date date,
@time time(7),
@duration int
)
as

begin

	Insert into Event(Name,HallID,Date,Time,Duration)
	values (@name,@hall,@date,@time,@duration)
end
GO

-- %% [markdown]
-- # [dbo].[addHall]

-- %%
/****** Object:  StoredProcedure [dbo].[addHall]    Script Date: 8/21/2022 9:40:02 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[addHall]
(@name nvarchar(50))
as

begin

	Insert into Hall (Name) Values (@name);

	Select ID From Hall Where Name = @name; 
	
end
GO

-- %% [markdown]
-- # [dbo].[addPrice]

-- %%
/****** Object:  StoredProcedure [dbo].[addPrice]    Script Date: 8/21/2022 9:40:02 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[addPrice]
(@price int,
@block int,
@event int,
@row int
)
as

begin

	Insert into Price (BlockId,EventId,Price,Idx)
	values (@block, @event, @price,@row)
end
GO

-- %% [markdown]
-- # [dbo].[addReservation]

-- %%
/****** Object:  StoredProcedure [dbo].[addReservation]    Script Date: 8/21/2022 9:40:02 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[addReservation]
(@n nvarchar(50),
@m nvarchar(50),
@c int,
@ev int)
as

begin
	
	Insert into Reservation (Name, Mail, Cost, EventId)
	values (@n, @m, @c, @ev)

	select ID FROM Reservation where Mail = @m and EventId= @ev;
	
end
GO

-- %% [markdown]
-- # [dbo].[addTicket]

-- %%
/****** Object:  StoredProcedure [dbo].[addTicket]    Script Date: 8/21/2022 9:40:02 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[addTicket]
(@rev int,
@blk int,
@x int,
@y int)
as

begin
	
	Insert into Ticket (ReservationId,BlockId,SeatX,SeatY)
	values (@rev,@blk,@x,@y)
	
end
GO

-- %% [markdown]
-- # [dbo].[altPrice]

-- %%
/****** Object:  StoredProcedure [dbo].[altPrice]    Script Date: 8/21/2022 9:40:02 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[altPrice]
(@price int,
@block int,
@event int,
@row int
)
as

begin

	update Price 
	Set Price = @price
	where EventId = @event and BlockId = @block and Idx = @row;
end
GO

-- %% [markdown]
-- # [dbo].[fetchBlock]

-- %%
/****** Object:  StoredProcedure [dbo].[fetchBlock]    Script Date: 8/21/2022 9:40:02 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[fetchBlock]
(@id int)
as

begin

	Select * from Block where ID = @id
	
end
GO

-- %% [markdown]
-- # [dbo].[fetchBlocks]

-- %%
/****** Object:  StoredProcedure [dbo].[fetchBlocks]    Script Date: 8/21/2022 9:40:02 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[fetchBlocks]
(@hall int)
as

begin

	Select * from Block where HallId = @hall
	
end
GO

-- %% [markdown]
-- # [dbo].[fetchEvent]

-- %%
/****** Object:  StoredProcedure [dbo].[fetchEvent]    Script Date: 8/21/2022 9:40:02 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[fetchEvent]
(@hall int)
as

begin

	Select * From Event Where HallID = @hall
end
GO

-- %% [markdown]
-- # [dbo].[fetchEvents]

-- %%
/****** Object:  StoredProcedure [dbo].[fetchEvents]    Script Date: 8/21/2022 9:40:02 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[fetchEvents]
as

begin

	Select * From Event
	
end
GO

-- %% [markdown]
-- # [dbo].[fetchHall]

-- %%
/****** Object:  StoredProcedure [dbo].[fetchHall]    Script Date: 8/21/2022 9:40:02 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[fetchHall]
as

begin

	Select * From Hall;
	
end
GO

-- %% [markdown]
-- # [dbo].[fetchPrices]

-- %%
/****** Object:  StoredProcedure [dbo].[fetchPrices]    Script Date: 8/21/2022 9:40:02 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
create procedure [dbo].[fetchPrices]
(@ev int)
as

begin

	Select * from Price where EventId = @ev;
end
GO

-- %% [markdown]
-- # [dbo].[fetchSeats]

-- %%
/****** Object:  StoredProcedure [dbo].[fetchSeats]    Script Date: 8/21/2022 9:40:02 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE procedure [dbo].[fetchSeats]
(@ev int)
as

begin

	Select t.BlockId, t.SeatX, t.SeatY 
	From Ticket t
	Join Reservation r
	On r.ID = t.ReservationId
	where r.EventId = @ev
end
GO

-- %% [markdown]
-- # [POS]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [POS] SET  READ_WRITE 
GO
